# %%
import os

# Specify the filename (including the full path if necessary)
file_name = 'HIstoricalPricesMSFT.csv'

# Get the current working directory
cwd = os.getcwd()

# Join the current working directory with the filename
file_path = os.path.join(cwd, file_name)

# Print the file path
print("File path:", file_path)
# Out:
# File path: C:\Users\pnuda\HIstoricalPricesMSFT.csv

# %%
import pandas as pd
import numpy as np

# Read the CSV file into a pandas DataFrame
file_path = r'C:\Users\pnuda\Downloads\HistoricalPricesMSFT.csv'
df = pd.read_csv(file_path)


# Display the DataFrame
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0     03/06/24  402.97  405.16  398.39  402.09  22344150
# 1     03/05/24  413.96  414.25  400.64  402.65  26919180
# 2     03/04/24  413.44  417.35  412.32  414.92  17595961
# 3     03/01/24  411.27  415.87  410.88  415.50  17823449
# 4     02/29/24  408.64  414.20  405.92  413.64  31947260
# ...        ...     ...     ...     ...     ...       ...
# 2552  01/14/14   34.73   35.88   34.63   35.78  41627328
# 2553  01/13/14   35.99   36.02   34.83   34.98  45923871
# 2554  01/10/14   35.90   36.15   35.75   36.04  40558770
# 2555  01/09/14   35.88   35.91   35.40   35.53  36520449
# 2556  01/08/14   36.00   36.14   35.58   35.76  59979539
#
# [2557 rows x 6 columns]

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y')
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0 2024-03-06  402.97  405.16  398.39  402.09  22344150
# 1 2024-03-05  413.96  414.25  400.64  402.65  26919180
# 2 2024-03-04  413.44  417.35  412.32  414.92  17595961
# 3 2024-03-01  411.27  415.87  410.88  415.50  17823449
# 4 2024-02-29  408.64  414.20  405.92  413.64  31947260

# %%
#Replace '?' with 'NaN'
df.replace('?',np.nan, inplace = True)
df.head()
# Out:
#         Date    Open    High     Low   Close    Volume
# 0 2024-03-06  402.97  405.16  398.39  402.09  22344150
# 1 2024-03-05  413.96  414.25  400.64  402.65  26919180
# 2 2024-03-04  413.44  417.35  412.32  414.92  17595961
# 3 2024-03-01  411.27  415.87  410.88  415.50  17823449
# 4 2024-02-29  408.64  414.20  405.92  413.64  31947260

# %%
print(df.dtypes)
# Out:
# Date       datetime64[ns]
#  Open             float64
#  High             float64
#  Low              float64
#  Close            float64
#  Volume             int64
# dtype: object

# %%
print(df.describe(include='all'))
# Out:
#                                 Date         Open         High          Low  \
# count                           2557  2557.000000  2557.000000  2557.000000
# mean   2019-02-04 14:14:52.608525568   154.376738   155.898673   152.809984
# min              2014-01-08 00:00:00    34.730000    35.880000    34.630000
# 25%              2016-07-22 00:00:00    56.290000    56.750000    55.780000
# 50%              2019-02-06 00:00:00   111.940000   112.950000   111.170000
# 75%              2021-08-19 00:00:00   246.550000   249.840000   244.690000
# max              2024-03-06 00:00:00   420.555000   420.820000   415.090000
# std                              NaN   105.928075   106.984281   104.830085
#
#              Close        Volume
# count  2557.000000  2.557000e+03
# mean    154.432836  3.004846e+07
# min      34.980000  7.425603e+06
# 25%      56.310000  2.165646e+07
# 50%     112.130000  2.679912e+07
# 75%     247.490000  3.414089e+07
# max     420.550000  2.025265e+08
# ...

# %%
# Sort the DataFrame by 'Date'
df.sort_values(by='Date', inplace=True)
df.head()
# Out:
#            Date   Open   High    Low   Close    Volume
# 2556 2014-01-08  36.00  36.14  35.58   35.76  59979539
# 2555 2014-01-09  35.88  35.91  35.40   35.53  36520449
# 2554 2014-01-10  35.90  36.15  35.75   36.04  40558770
# 2553 2014-01-13  35.99  36.02  34.83   34.98  45923871
# 2552 2014-01-14  34.73  35.88  34.63   35.78  41627328

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2557 entries, 2556 to 0
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2557 non-null   datetime64[ns]
#  1    Open    2557 non-null   float64
#  2    High    2557 non-null   float64
#  3    Low     2557 non-null   float64
#  4    Close   2557 non-null   float64
#  5    Volume  2557 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 139.8 KB
# None

# %%
#Count missing values in each column
missing_data = df.isnull()
missing_data.head(5)
#Using a for loop in Python, you can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value and "False" means the value is present in the data set. In the body of the for loop the method ".value_counts()" counts the number of "True" values.
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Date
# Date
# False    2557
# Name: count, dtype: int64
#
#  Open
#  Open
# False    2557
# Name: count, dtype: int64
#
#  High
#  High
# False    2557
# Name: count, dtype: int64
#
#  Low
#  Low
# False    2557
# Name: count, dtype: int64
#
#  Close
#  Close
# False    2557
# Name: count, dtype: int64
#
#  Volume
#  Volume
# False    2557
# Name: count, dtype: int64

# %%
# Print the column names to verify
print(df.columns)
# Out:
# Index(['Date', ' Open', ' High', ' Low', ' Close', ' Volume'], dtype='object')

# %%
df[[' Open', ' High', ' Low', ' Close',' Volume']].corr()
# Out:
#              Open      High       Low     Close    Volume
#  Open    1.000000  0.999875  0.999862  0.999703 -0.102311
#  High    0.999875  1.000000  0.999821  0.999852 -0.097704
#  Low     0.999862  0.999821  1.000000  0.999867 -0.107792
#  Close   0.999703  0.999852  0.999867  1.000000 -0.103370
#  Volume -0.102311 -0.097704 -0.107792 -0.103370  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Low as potential predictor variable of Close
sns.regplot(x=" Low", y=" Close", data=df)
plt.ylim(0,)
# Out:
# (0.0, 439.83046554811216)

# %%
# High as potential predictor variable of Close
sns.regplot(x=" High", y=" Close", data=df)
plt.ylim(0,)
# Out:
# (0.0, 439.8285)

# %%
# Open as potential predictor variable of Close
sns.regplot(x=" Open", y=" Close", data=df)
plt.ylim(0,)
# Out:
# (0.0, 440.3296776071168)

# %%
# Volume as potential predictor variable of Close
sns.regplot(x=" Volume", y=" Close", data=df)
plt.ylim(0,)
# Out:
# (0.0, 442.8934374710456)

# %%
df[' Close'].value_counts()
# Out:
#  Close
# 62.30     4
# 64.62     3
# 47.00     3
# 46.76     3
# 45.65     3
#          ..
# 85.51     1
# 85.50     1
# 85.52     1
# 85.83     1
# 402.09    1
# Name: count, Length: 2364, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming you have the data stored in a DataFrame named 'df'
# If not, you can read it from a CSV file or any other source

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df[' Close'], marker='o', linestyle='-')

# Adding labels and title
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45)

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df[' Volume'], df[' Close'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.10336951045253522  with a P-value of P = 1.6184633355414753e-07

# %%
pearson_coef, p_value = stats.pearsonr(df[' Open'], df[' Close'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9997031659818506  with a P-value of P = 0.0

# %%
pearson_coef, p_value = stats.pearsonr(df[' High'], df[' Close'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.9998518612845239  with a P-value of P = 0.0

# %%
pearson_coef, p_value = stats.pearsonr(df[' Low'], df[' Close'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.999867499908947  with a P-value of P = 0.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore", category=UserWarning) 
# %matplotlib inline

# %%
lm = LinearRegression()

X = df[[' Volume']]
Y = df[' Close']

lm.fit(X,Y)

Yhat=lm.predict(X)

# %%
ax1 = sns.distplot(df[' Close'], hist=False, color="r", label="Actual Values")

# Create a distribution plot for predicted values
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Closing Price')
plt.ylabel('Volume of Stock Traded')
plt.legend(['Actual Value', 'Predicted Value'])
plt.show()

# %%
lm = LinearRegression()

X = df[[' Open']]
Y = df[' Close']

lm.fit(X,Y)

Yhat=lm.predict(X)

# %%
ax2 = sns.distplot(df[' Close'], hist=False, color="red", label="Actual Values")

# Create a distribution plot for predicted values
sns.distplot(Yhat, hist=False, color="blue", label="Fitted Values" , ax=ax2)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Closing Price')
plt.ylabel('Opening Price of Stock')
plt.legend(['Actual Value', ' Predicted Value'])
plt.show()

# %%
lm = LinearRegression()

X = df[[' High']]
Y = df[' Close']

lm.fit(X,Y)

Yhat=lm.predict(X)

# %%
ax3 = sns.distplot(df[' Close'], hist=False, color="r", label="Actual Value")

# Create a distribution plot for predicted values
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax3)

plt.title('Actual vs Fitted Values for ClosingPrice')
plt.xlabel('Closing Value of Stock')
plt.ylabel('Highest Stcok Price for the period')
plt.legend(['Actual Value', 'Predicted Value'])
plt.show()

# %%
lm = LinearRegression()

X = df[[' Low']]
Y = df[' Close']

lm.fit(X,Y)

Yhat=lm.predict(X)

# %%
ax4 = sns.distplot(df[' Close'], hist=False, color="r", label="Actual Value")

# Create a distribution plot for predicted values
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax4)

plt.title('Actual vs Fitted Values for ClosingPrice')
plt.xlabel('Closing Value of Stock')
plt.ylabel('Lowest Stock Price for the period')
plt.legend(['Actual Value', 'Predicted Value'])
plt.show()

# %%
mse_slr = mean_squared_error(df[' Close'], Yhat)
r2_score_slr = lm.score(X, Y)
print('The R-square for Linear Regression is: ', r2_score_slr)
print('The mean square error of Closing price and predicted value is: ', mse_slr)
# Out:
# The R-square for Linear Regression is:  0.9997350173741683
# The mean square error of Closing price and predicted value is:  2.9739985474111994

# %%
lm1 = LinearRegression()
Z = df[[' Open',' High',' Low',' Volume']]
lm1.fit(Z,Y)
Y_hat = lm1.predict(Z)

# %%
ax1 = sns.distplot(df[' Close'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Closing Price')
plt.ylabel('Factors Impacting')
# Out:
# Text(0, 0.5, 'Factors Impacting')

# %%
# Calculate daily percentage change in stock prices
df['PriceChange'] = df[' Close'].pct_change() * 100

# Derive sentiment indicators based on the percentage change
df['Sentiment'] = df['PriceChange'].apply(lambda x: 1 if x > 0 else 0)

# Convert the 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Aggregate sentiment indicators over a period of differing years
# For example, you can resample the data annually and calculate the mean sentiment for each year
sentiment_over_10_years = df.set_index('Date').resample('6M')['Sentiment'].mean()

# Print the aggregated sentiment over 10 years
print(sentiment_over_10_years)


# Now you can analyze and visualize the sentiment trends over the 10-year period
# Out:
# Date
# 2014-01-31    0.411765
# 2014-07-31    0.488000
# 2015-01-31    0.500000
# 2015-07-31    0.547619
# 2016-01-31    0.448000
# 2016-07-31    0.468254
# 2017-01-31    0.464567
# 2017-07-31    0.472000
# 2018-01-31    0.393701
# 2018-07-31    0.440000
# 2019-01-31    0.468254
# 2019-07-31    0.368000
# 2020-01-31    0.425197
# 2020-07-31    0.428571
# 2021-01-31    0.424000
# 2021-07-31    0.492063
# 2022-01-31    0.472441
# 2022-07-31    0.516129
# 2023-01-31    0.551181
# 2023-07-31    0.491935
# 2024-01-31    0.417323
# 2024-07-31    0.583333
# Freq: 6M, Name: Sentiment, dtype: float64
